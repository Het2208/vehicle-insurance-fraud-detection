# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.decomposition import PCA

# %%
df = pd.read_csv("insurance_fraud_data_preprocessed.csv")
df.sample()
# Out:
#       ohe__gender_F  ohe__gender_M  ohe__property_status_Own  \
# 8834      -0.964608       0.964608                  0.898865
#
#       ohe__property_status_Rent  ohe__claim_day_of_week_Friday  \
# 8834                  -0.898865                      -0.410965
#
#       ohe__claim_day_of_week_Monday  ohe__claim_day_of_week_Saturday  \
# 8834                      -0.407215                        -0.418146
#
#       ohe__claim_day_of_week_Sunday  ohe__claim_day_of_week_Thursday  \
# 8834                       2.441539                        -0.405544
#
#       ohe__claim_day_of_week_Tuesday  ...  remainder__days_open  \
# 8834                       -0.401913  ...              0.801172
#
#       remainder__form_defects  remainder__claim_year  remainder__claim_month  \
# 8834                 1.524745               1.016816               -1.316083
#
#       remainder__claim_day  remainder__claim_ratio  remainder__vehicle_old  \
# 8834               0.97133               -0.053461               -0.114795
#
#       remainder__weekend_claim  remainder__claim_vehicle_ratio  fraud_reported
# 8834                  1.559725                       -0.064803               1
#
# [1 rows x 55 columns]

# %%
X = df.drop(columns = ["fraud_reported"])
y = df.iloc[: ,-1]
print(X.shape)
print(y.shape)
# Out:
# (11994, 54)
# (11994,)

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size = 0.25 , random_state = 42)

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Accuracy matrics

# %%
from sklearn.metrics import accuracy_score , confusion_matrix , f1_score , precision_score , recall_score

# %% [markdown]
# ## Training Accuracy

# %%
y_pred_train = model.predict(X_train)

# %%
print(f"Accuracy score : " , accuracy_score(y_train , y_pred_train))
# Out:
# Accuracy score :  1.0

# %%
print("Confusion matrix : ")
confusion_matrix(y_train , y_pred_train)
# Out:
# Confusion matrix :
# array([[6766,    0],
#        [   0, 2229]])

# %%
print("Precision score : ")
precision_score(y_train , y_pred_train)
# Out:
# Precision score :
# 1.0

# %%
print("recall score : ")
recall_score(y_train , y_pred_train)
# Out:
# recall score :
# 1.0

# %%
print("f1 score : ")
f1_score(y_train , y_pred_train)
# Out:
# f1 score :
# 1.0

# %% [markdown]
# ## Testing Accuracy

# %%
y_pred_test = model.predict(X_test)

# %%
print(f"Accuracy score : " , accuracy_score(y_test , y_pred_test))
# Out:
# Accuracy score :  0.6875625208402801

# %%
print("Confusion matrix : ")
confusion_matrix(y_test , y_pred_test)
# Out:
# Confusion matrix :
# array([[1805,  472],
#        [ 465,  257]])

# %%
print("Precision score : ")
precision_score(y_test , y_pred_test)
# Out:
# Precision score :
# 0.35253772290809327

# %%
print("recall score : ")
recall_score(y_test , y_pred_test)
# Out:
# recall score :
# 0.3559556786703601

# %%
print("f1 score : ")
f1_score(y_test , y_pred_test)
# Out:
# f1 score :
# 0.3542384562370779

# %% [markdown]
# # Cross Validation score for 10 times

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(model,X_train,y_train,cv=10,scoring='accuracy')

# %%
scores.mean()
# Out:
# np.float64(0.6601447287109133)

# %% [markdown]
# # Hyperparameter tunning

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth': [2, 4, 6, 8, 10, None],
    'criterion': ['gini', 'entropy'],
    'max_features': [None, 'sqrt', 'log2'],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 5, 10]
}

t = GridSearchCV(
    DecisionTreeClassifier(random_state=42),
    param_grid=param_grid,
    scoring='accuracy',
    n_jobs=-1
)

t.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 4, 6, 8, 10, None],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 5, 10],
#                          'min_samples_split': [2, 5, 10, 20]},
#              scoring='accuracy')

# %%
t.best_score_
# Out:
# np.float64(0.7766536964980545)

# %%
t.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 2,
#  'max_features': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2}

# %% [markdown]
# ### Grid search's cross validation score

# %%
scores = cross_val_score(t,X_train,y_train,cv=10,scoring='accuracy')

# %%
scores.mean()
# Out:
# np.float64(0.776097392164133)

# %% [markdown]
# # Ensemble Model

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in E:\AnacondaSetup\Lib\site-packages (3.4.1)
# Requirement already satisfied: numpy in E:\AnacondaSetup\Lib\site-packages (from xgboost) (2.3.5)
# Requirement already satisfied: scipy in E:\AnacondaSetup\Lib\site-packages (from xgboost) (1.16.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (E:\AnacondaSetup\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (E:\AnacondaSetup\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (E:\AnacondaSetup\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from xgboost import XGBClassifier

# %%
xg = XGBClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=3,
    random_state=42
)

# %%
print(X_train.columns)
# Out:
# Index(['ohe__gender_F', 'ohe__gender_M', 'ohe__property_status_Own',
#        'ohe__property_status_Rent', 'ohe__claim_day_of_week_Friday',
#        'ohe__claim_day_of_week_Monday', 'ohe__claim_day_of_week_Saturday',
#        'ohe__claim_day_of_week_Sunday', 'ohe__claim_day_of_week_Thursday',
#        'ohe__claim_day_of_week_Tuesday', 'ohe__claim_day_of_week_Wednesday',
#        'ohe__accident_site_Highway', 'ohe__accident_site_Local',
#        'ohe__accident_site_Parking Lot', 'ohe__channel_Broker',
#        'ohe__channel_Online', 'ohe__channel_Phone', 'ohe__vehicle_color_black',
#        'ohe__vehicle_color_blue', 'ohe__vehicle_color_gray',
#        'ohe__vehicle_color_other', 'ohe__vehicle_color_red',
#        'ohe__vehicle_color_silver', 'ohe__vehicle_color_white',
#        'ohe__income_group_(-1.601, 56899.2]',
#        'ohe__income_group_(56899.2, 60899.2]',
#        'ohe__income_group_(60899.2, 64699.2]',
#        'ohe__income_group_(64699.2, 257313.6]', 'ord__vehicle_category',
#        'remainder__age_of_driver', 'remainder__marital_status',
#        'remainder__safety_rating', 'remainder__annual_income',
#        'remainder__high_education', 'remainder__address_change',
#        'remainder__past_num_of_claims', 'remainder__witness_present',
#        'remainder__liab_prct', 'remainder__police_report',
#        'remainder__age_of_vehicle', 'remainder__vehicle_price',
#        'remainder__total_claim', 'remainder__injury_claim',
#        'remainder__policy_deductible', 'remainder__annual_premium',
#        'remainder__days_open', 'remainder__form_defects',
#        'remainder__claim_year', 'remainder__claim_month',
#        'remainder__claim_day', 'remainder__claim_ratio',
#        'remainder__vehicle_old', 'remainder__weekend_claim',
#        'remainder__claim_vehicle_ratio'],
#       dtype='object')

# %%
X_train.columns = (
    X_train.columns
    .str.replace('[', '(', regex=False)
    .str.replace(']', ')', regex=False)
    .str.replace('<', 'less_than', regex=False)
)

X_test.columns = (
    X_test.columns
    .str.replace('[', '(', regex=False)
    .str.replace(']', ')', regex=False)
    .str.replace('<', 'less_than', regex=False)
)

# %%
xg.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
print("Train Accuracy:", xg.score(X_train, y_train))
print("Test Accuracy:", xg.score(X_test, y_test))
# Out:
# Train Accuracy: 0.7822123401889939
# Test Accuracy: 0.7775925308436146

# %%
scores = cross_val_score(model,X_train,y_train,cv=5,scoring='accuracy')

# %%
scores.mean()
# Out:
# np.float64(0.7787659811006115)

# %% [markdown]
# ## Grid search on Ensemble model

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    "n_estimators": [100, 200, 300],
    "learning_rate": [0.01, 0.05, 0.1],
    "max_depth": [3, 5, 7],
    "subsample": [0.8, 1.0],
    "colsample_bytree": [0.8, 1.0]
}

# %%
grid = GridSearchCV(
    estimator=xg,
    param_grid=param_grid,
    cv=5,
    scoring="accuracy",
    n_jobs=-1,
    verbose=1
)

grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=True, eval_metric=None,
#                                      feature_types=None, feature_weights=None,
#                                      gamma=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None...
#                                      max_delta_step=None, max_depth=3,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=100,
#                                      n_jobs=None, num_parallel_tree=None, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.8, 1.0],
#                          'learning_rate': [0.01, 0.05, 0.1],
#                          'max_depth': [3, 5, 7],
#                          'n_estimators': [100, 200, 300],
#                          'subsample': [0.8, 1.0]},
#              scoring='accuracy', verbose=1)

# %%
grid.best_score_
# Out:
# np.float64(0.7767648693718733)

# %%
grid.best_params_
# Out:
# {'colsample_bytree': 0.8,
#  'learning_rate': 0.01,
#  'max_depth': 5,
#  'n_estimators': 300,
#  'subsample': 0.8}

# %%
grid.score(X_test, y_test)
# Out:
# 0.784594864954985
