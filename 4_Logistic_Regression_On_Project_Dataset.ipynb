# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("insurance_fraud_data_preprocessed.csv")
df.sample()
# Out:
#       ohe__gender_F  ohe__gender_M  ohe__property_status_Own  \
# 8279       1.036691      -1.036691                  0.898865
#
#       ohe__property_status_Rent  ohe__claim_day_of_week_Friday  \
# 8279                  -0.898865                      -0.410965
#
#       ohe__claim_day_of_week_Monday  ohe__claim_day_of_week_Saturday  \
# 8279                      -0.407215                        -0.418146
#
#       ohe__claim_day_of_week_Sunday  ohe__claim_day_of_week_Thursday  \
# 8279                      -0.409578                        -0.405544
#
#       ohe__claim_day_of_week_Tuesday  ...  remainder__days_open  \
# 8279                        2.488101  ...             -0.200301
#
#       remainder__form_defects  remainder__claim_year  remainder__claim_month  \
# 8279                 0.518318               1.016816                 1.29869
#
#       remainder__claim_day  remainder__claim_ratio  remainder__vehicle_old  \
# ...

# %%
X = df.drop(columns = ["fraud_reported"])
y = df.iloc[: ,-1]
print(X.shape)
print(y.shape)
# Out:
# (11994, 54)
# (11994,)

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size = 0.25 , random_state = 42)

# %%
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score , confusion_matrix

# %%
print(f"Accuracy score : {accuracy_score(y_test , y_pred)}")
# Out:
# Accuracy score : 0.782594198066022

# %%
import joblib

my_model = model

file_path = "veh_ins_fraud.pkl"

# Save the object to the file
joblib.dump(my_model, file_path)
print(f"File successfully saved to {file_path}")
# Out:
# File successfully saved to veh_ins_fraud.pkl

# %% [markdown]
# # Manual Implementation of Logistic Regression
#
# ## Uses sigmoid function
# ## Maximum Likelihood Estimation
# ## Log loss of maximum likelihhod
# ## Gradient Descent with derivative of log loss

# %%
import numpy as np

class LogisticRegression:

    def __init__(self, learning_rate=0.01, epochs=1000):
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.weights = None
        self.bias = None

    # Sigmoid Function
    def sigmoid(self, z):
        return 1 / (1 + np.exp(-z))

    # Train Model
    def fit(self, X, y):

        n_samples, n_features = X.shape

        # Initialize Parameters
        self.weights = np.zeros(n_features)
        self.bias = 0

        # Gradient Descent
        for _ in range(self.epochs):

            # Step 1: Linear Combination
            z = np.dot(X, self.weights) + self.bias

            # Step 2: Sigmoid
            y_pred = self.sigmoid(z)

            # Step 3: Compute Gradients
            dw = (1 / n_samples) * np.dot(X.T, (y_pred - y))
            db = (1 / n_samples) * np.sum(y_pred - y)

            # Step 4: Update Parameters
            self.weights -= self.learning_rate * dw
            self.bias -= self.learning_rate * db

    # Predict Probability
    def predict_proba(self, X):
        z = np.dot(X, self.weights) + self.bias
        return self.sigmoid(z)

    # Predict Class
    def predict(self, X):
        probabilities = self.predict_proba(X)
        return (probabilities >= 0.5).astype(int)

# %%
Manualmodel = LogisticRegression()

# %%
Manualmodel = LogisticRegression()
Manualmodel.fit(X_train,y_train)

# %%
y_pred = Manualmodel.predict(X_test)

# %%
print(f"Accuracy score : {accuracy_score(y_test , y_pred)}")
# Out:
# Accuracy score : 0.7802600866955652
