# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.decomposition import PCA

# %%
df = pd.read_csv("insurance_fraud_data_preprocessed.csv")
df.sample()
# Out:
#       ohe__gender_F  ohe__gender_M  ohe__property_status_Own  \
# 7288      -0.964608       0.964608                 -1.112514
#
#       ohe__property_status_Rent  ohe__claim_day_of_week_Friday  \
# 7288                   1.112514                      -0.410965
#
#       ohe__claim_day_of_week_Monday  ohe__claim_day_of_week_Saturday  \
# 7288                       2.455704                        -0.418146
#
#       ohe__claim_day_of_week_Sunday  ohe__claim_day_of_week_Thursday  \
# 7288                      -0.409578                        -0.405544
#
#       ohe__claim_day_of_week_Tuesday  ...  remainder__days_open  \
# 7288                       -0.401913  ...              1.020202
#
#       remainder__form_defects  remainder__claim_year  remainder__claim_month  \
# 7288                 1.021531               1.016816                0.136569
#
#       remainder__claim_day  remainder__claim_ratio  remainder__vehicle_old  \
# 7288              1.414174               -0.063658               -0.114795
#
#       remainder__weekend_claim  remainder__claim_vehicle_ratio  fraud_reported
# 7288                 -0.641139                        0.533009               0
#
# [1 rows x 55 columns]

# %%
X = df.drop(columns = ["fraud_reported"])
y = df.iloc[: ,-1]
print(X.shape)
print(y.shape)
# Out:
# (11994, 54)
# (11994,)

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size = 0.25 , random_state = 42)

# %%
pca = PCA(n_components=7)
X_train_trf = pca.fit_transform(X_train)
X_test_trf = pca.transform(X_test)

# %%
from sklearn.metrics import accuracy_score , confusion_matrix , f1_score , precision_score , recall_score

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV

# %%
xg = XGBClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=3,
    random_state=42
)

# %%
X_train.columns = (
    X_train.columns
    .str.replace('[', '(', regex=False)
    .str.replace(']', ')', regex=False)
    .str.replace('<', 'less_than', regex=False)
)

X_test.columns = (
    X_test.columns
    .str.replace('[', '(', regex=False)
    .str.replace(']', ')', regex=False)
    .str.replace('<', 'less_than', regex=False)
)

# %%
xg.fit(X_train_trf, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = xg.predict(X_test_trf)
print(f"Accuracy score : " , accuracy_score(y_test , y_pred))
# Out:
# Accuracy score :  0.764921640546849

# %%
param_grid = {
    "n_estimators": [100, 200, 300],
    "learning_rate": [0.01, 0.05, 0.1],
    "max_depth": [3, 5, 7],
    "subsample": [0.8, 1.0],
    "colsample_bytree": [0.8, 1.0]
}

# %%
grid = GridSearchCV(
    estimator=xg,
    param_grid=param_grid,
    cv=5,
    scoring="accuracy",
    n_jobs=-1,
    verbose=1
)

grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=True, eval_metric=None,
#                                      feature_types=None, feature_weights=None,
#                                      gamma=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None...
#                                      max_delta_step=None, max_depth=3,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=100,
#                                      n_jobs=None, num_parallel_tree=None, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.8, 1.0],
#                          'learning_rate': [0.01, 0.05, 0.1],
#                          'max_depth': [3, 5, 7],
#                          'n_estimators': [100, 200, 300],
#                          'subsample': [0.8, 1.0]},
#              scoring='accuracy', verbose=1)

# %%
grid.best_score_
# Out:
# np.float64(0.7767648693718733)

# %%
grid.best_params_
# Out:
# {'colsample_bytree': 0.8,
#  'learning_rate': 0.01,
#  'max_depth': 5,
#  'n_estimators': 300,
#  'subsample': 0.8}

# %%
grid.score(X_test, y_test)
# Out:
# 0.784594864954985

# %%
import joblib

my_model = grid

file_path = "final.pkl"

# Save the object to the file
joblib.dump(my_model, file_path)
print(f"File successfully saved to {file_path}")
# Out:
# File successfully saved to final.pkl

# %%
pca = PCA()
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

components = [10, 20, 30, 40, 50, 75, 100, 125, 150, 200, 250, 300, 350, 400, 500, 600, 700]

best_accuracy = 0
best_n_components = 0

print("n_components\tAccuracy")

for i in components:
    # Select first i principal components
    X_train_trf = X_train_pca[:, :i]
    X_test_trf = X_test_pca[:, :i]

    # Train KNN
    knn = KNeighborsClassifier()
    knn.fit(X_train_trf, y_train)

    # Predict and calculate accuracy
    y_pred = knn.predict(X_test_trf)
    acc = accuracy_score(y_test, y_pred)

    print(f"{i}\t\t{acc:.4f}")

    # Store the best result
    if acc > best_accuracy:
        best_accuracy = acc
        best_n_components = i

print("\n==============================")
print(f"Best PCA Components : {best_n_components}")
print(f"Best Accuracy       : {best_accuracy:.4f}")
# Out:
# n_components	Accuracy
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 18
#      15 X_test_trf = X_test_pca[:, :i]
#      17 # Train KNN
# ---> 18 knn = KNeighborsClassifier()
#      19 knn.fit(X_train_trf, y_train)
#      21 # Predict and calculate accuracy
#
# NameError: name 'KNeighborsClassifier' is not defined
