# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Machine Learning - 2301CS621</b></center>
# <center><b><h1>Kanasagara Het (206)</b></center>
# <pre>

# %% [markdown]
# # Exploratory Data Analysis (EDA) Of vehicle insurance fraud detection

# %%
import pandas as pd
df = pd.read_csv("insurance_fraud_data.csv")
df
# Out:
#        claim_number  age_of_driver gender marital_status  safety_rating  \
# 0            414724             39      M              1             73
# 1            269568             33      M              1             72
# 2            974592             31      M              1             76
# 3            995328             53      F              1             93
# 4           1140480             41      M              1             87
# ...             ...            ...    ...            ...            ...
# 11997     621727488             34      M              1             88
# 11998     621810432             65      F              1             97
# 11999     621872640             64      F              1             87
# 12000     621914112             34      F              1             70
# 12001     621955584             45      M              1             61
#
#        annual_income  high_education  address_change property_status  \
# ...

# %% [markdown]
# # 1. Dataset Overview
#
# Dataset Overview is the first step in **Exploratory Data Analysis (EDA)**. It provides a quick understanding of the dataset's structure, size, and features before performing further analysis.
#
# ### Questions
#
# 1. What is the shape of the dataset?
# 2. How many rows are there?
# 3. How many columns are there?
# 4. What is the data type of each column?
# 5. Print the name of all the columns.

# %%
df.shape
# Out:
# (12002, 29)

# %%
df.shape[0]
# Out:
# 12002

# %%
df.shape[1]
# Out:
# 29

# %%
df.dtypes
# Out:
# claim_number            int64
# age_of_driver           int64
# gender                 object
# marital_status         object
# safety_rating           int64
# annual_income         float64
# high_education          int64
# address_change          int64
# property_status        object
# zip_code                int64
# claim_date             object
# claim_day_of_week      object
# accident_site          object
# past_num_of_claims      int64
# witness_present        object
# liab_prct               int64
# channel                object
# police_report           int64
# age_of_vehicle         object
# vehicle_category       object
# vehicle_price         float64
# vehicle_color          object
# total_claim           float64
# injury_claim           object
# policy deductible       int64
# annual premium        float64
# days open             float64
# form defects            int64
# fraud reported         object
# dtype: object

# %%
df.columns
# Out:
# Index(['claim_number', 'age_of_driver', 'gender', 'marital_status',
#        'safety_rating', 'annual_income', 'high_education', 'address_change',
#        'property_status', 'zip_code', 'claim_date', 'claim_day_of_week',
#        'accident_site', 'past_num_of_claims', 'witness_present', 'liab_prct',
#        'channel', 'police_report', 'age_of_vehicle', 'vehicle_category',
#        'vehicle_price', 'vehicle_color', 'total_claim', 'injury_claim',
#        'policy deductible', 'annual premium', 'days open', 'form defects',
#        'fraud reported'],
#       dtype='object')

# %% [markdown]
# # 2. DataFrame Summary
#
# A **DataFrame Summary** provides a statistical overview of the dataset. It helps you quickly understand the distribution, central tendency, spread, and count of values in numerical columns. You can summarize the entire DataFrame or focus on specific columns based on your analysis needs.
#
# ### Questions
#
# 1. Summarize the entire DataFrame.
# 2. Summarize all the columns.
# 3. Summarize any one particular column.
# 4. Summarize any two or more columns at once.
# 5. How many Duplicate rows in dataset

# %%
df.describe()
# Out:
#        claim_number  age_of_driver  safety_rating  annual_income  \
# count  1.200200e+04   12002.000000   12002.000000   12002.000000
# mean   3.119801e+08      43.525162      73.702966   63658.226534
# std    1.795997e+08      12.201298      15.378967   17289.704559
# min    1.866240e+05      19.000000       2.000000      -1.600000
# 25%    1.561887e+08      35.000000      66.000000   56899.200000
# 50%    3.121908e+08      43.000000      76.000000   60899.200000
# 75%    4.677938e+08      51.000000      85.000000   64697.600000
# max    6.220385e+08     278.000000     100.000000  257313.600000
#
#        high_education  address_change      zip_code  past_num_of_claims  \
# count    12002.000000    12002.000000  12002.000000        12002.000000
# mean         0.698134        0.576737  49762.387269            0.494918
# std          0.459087        0.494097  29133.180765            0.956002
# min          0.000000        0.000000      0.000000            0.000000
# ...

# %%
df.describe(include="all")
# Out:
#         claim_number  age_of_driver gender marital_status  safety_rating  \
# count   1.200200e+04   12002.000000  12002          12002   12002.000000
# unique           NaN            NaN      2              3            NaN
# top              NaN            NaN      M              1            NaN
# freq             NaN            NaN   6216           8582            NaN
# mean    3.119801e+08      43.525162    NaN            NaN      73.702966
# std     1.795997e+08      12.201298    NaN            NaN      15.378967
# min     1.866240e+05      19.000000    NaN            NaN       2.000000
# 25%     1.561887e+08      35.000000    NaN            NaN      66.000000
# 50%     3.121908e+08      43.000000    NaN            NaN      76.000000
# 75%     4.677938e+08      51.000000    NaN            NaN      85.000000
# max     6.220385e+08     278.000000    NaN            NaN     100.000000
#
#         annual_income  high_education  address_change property_status  \
# ...

# %%
df["vehicle_price"].describe()
# Out:
# count     12002.000000
# mean      22925.335594
# std       12108.888412
# min        2261.507903
# 25%       14087.559950
# 50%       20642.029325
# 75%       29293.641235
# max      106991.684500
# Name: vehicle_price, dtype: float64

# %%
df[["vehicle_category" , "vehicle_price" , "vehicle_color"]].describe(include="all")
# Out:
#        vehicle_category  vehicle_price vehicle_color
# count             12002   12002.000000         12002
# unique                3            NaN             7
# top             Compact            NaN           red
# freq               4033            NaN          1766
# mean                NaN   22925.335594           NaN
# std                 NaN   12108.888412           NaN
# min                 NaN    2261.507903           NaN
# 25%                 NaN   14087.559950           NaN
# 50%                 NaN   20642.029325           NaN
# 75%                 NaN   29293.641235           NaN
# max                 NaN  106991.684500           NaN

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 3. Selecting Columns
#
# Selecting columns allows you to extract one or more specific columns from a DataFrame for analysis. This helps you focus only on the relevant data instead of working with the entire dataset.
#
# ### Questions
#
# 1. Select and display the **`age_of_driver`** column.
# 2. Select and display the **`vehicle_category`**, **`vehicle_price`**, and **`vehicle_color`** columns.
# 3. Select the **`vehicle_category`**, **`vehicle_price`**, and **`vehicle_color`** columns, and display only the **last 10 records**.
# 4. Store the **`annual_income`** column as a Pandas **Series** named **`yearly_income`**, and print its data type.

# %%
df["age_of_driver"]
# Out:
# 0        39
# 1        33
# 2        31
# 3        53
# 4        41
#          ..
# 11997    34
# 11998    65
# 11999    64
# 12000    34
# 12001    45
# Name: age_of_driver, Length: 12002, dtype: int64

# %%
df[["vehicle_category" , "vehicle_price" , "vehicle_color"]]
# Out:
#       vehicle_category  vehicle_price vehicle_color
# 0                Large   24360.592730        silver
# 1               Medium   23457.352820         black
# 2               Medium   19752.425230          gray
# 3               Medium   32910.342240           red
# 4               Medium   28570.376750           red
# ...                ...            ...           ...
# 11997            Large   24134.334750           red
# 11998          Compact   57417.739270          gray
# 11999            Large   20231.723630         other
# 12000          Compact   21900.031920         black
# 12001           Medium    8291.858346           red
#
# [12002 rows x 3 columns]

# %%
df[["vehicle_category" , "vehicle_price" , "vehicle_color"]].tail(10)
# Out:
#       vehicle_category  vehicle_price vehicle_color
# 11992          Compact   13391.566810          gray
# 11993           Medium    6625.618162         black
# 11994           Medium   20732.814060          gray
# 11995            Large   50804.103420          gray
# 11996          Compact   43472.514050         white
# 11997            Large   24134.334750           red
# 11998          Compact   57417.739270          gray
# 11999            Large   20231.723630         other
# 12000          Compact   21900.031920         black
# 12001           Medium    8291.858346           red

# %%
yearly_income = df["annual_income"]
yearly_income
# Out:
# 0        58612.8
# 1        35936.0
# 2        84940.8
# 3        73526.4
# 4        59403.2
#           ...
# 11997    66505.6
# 11998    23315.2
# 11999    66505.6
# 12000    76409.6
# 12001    70915.2
# Name: annual_income, Length: 12002, dtype: float64

# %% [markdown]
# # 4. Filtering Data
#
# Filtering allows you to retrieve only the rows that satisfy one or more conditions. It helps you focus on specific records for analysis without modifying the original dataset.
#
# ### Questions
#
# 1. Display all records where the **`gender`** is **'M'**.
# 2. Display all records where the **`age_of_driver`** is greater than **40**.
# 3. Display all records where the **`annual_income`** is greater than **50000**.
# 4. Display all records where the **`vehicle_category`** is **'Medium'**.
# 5. Display all records where the **`fraud reported`** is **'Y'**.
# 6. Display all records where the **`fraud reported`** is **'N'**.
# 7. Display all records where the **`past_num_of_claims`** is greater than **2**.
# 8. Display all records where the **`age_of_driver`** is between **25** and **40**.
# 9. Display all records where the **`annual_income`** is greater than **50000** and the **`gender`** is **'F'**.
# 10. Display all records where the **`vehicle_category`** is **'Medium'** or **'Large'**.
# 11. Display the first **10** records where the **`fraud reported`** is **'Y'**.

# %%
df[df["gender"] == "M"]
# Out:
#        claim_number  age_of_driver gender marital_status  safety_rating  \
# 0            414724             39      M              1             73
# 1            269568             33      M              1             72
# 2            974592             31      M              1             76
# 4           1140480             41      M              1             87
# 6           1700352             50      M              1             89
# ...             ...            ...    ...            ...            ...
# 11992     621561600             69      M              1             83
# 11994     621644544             41      M              1             63
# 11995     621665280             42      M              0             71
# 11997     621727488             34      M              1             88
# 12001     621955584             45      M              1             61
#
#        annual_income  high_education  address_change property_status  \
# ...

# %%
df[df["age_of_driver"] > 40]
# Out:
#        claim_number  age_of_driver gender marital_status  safety_rating  \
# 3            995328             53      F              1             93
# 4           1140480             41      M              1             87
# 5           1244160             42      F              0             68
# 6           1700352             50      M              1             89
# 7           1804032             42      F              1             68
# ...             ...            ...    ...            ...            ...
# 11994     621644544             41      M              1             63
# 11995     621665280             42      M              0             71
# 11998     621810432             65      F              1             97
# 11999     621872640             64      F              1             87
# 12001     621955584             45      M              1             61
#
#        annual_income  high_education  address_change property_status  \
# ...

# %%
df[df["annual_income"] > 50000]
# Out:
#        claim_number  age_of_driver gender marital_status  safety_rating  \
# 0            414724             39      M              1             73
# 2            974592             31      M              1             76
# 3            995328             53      F              1             93
# 4           1140480             41      M              1             87
# 6           1700352             50      M              1             89
# ...             ...            ...    ...            ...            ...
# 11996     621706752             31      F              1             70
# 11997     621727488             34      M              1             88
# 11999     621872640             64      F              1             87
# 12000     621914112             34      F              1             70
# 12001     621955584             45      M              1             61
#
#        annual_income  high_education  address_change property_status  \
# ...

# %%
df[df["vehicle_category"] == "Medium"]
# Out:
#        claim_number  age_of_driver gender marital_status  safety_rating  \
# 1            269568             33      M              1             72
# 2            974592             31      M              1             76
# 3            995328             53      F              1             93
# 4           1140480             41      M              1             87
# 5           1244160             42      F              0             68
# ...             ...            ...    ...            ...            ...
# 11972     619923456             50      M              0             85
# 11986     620960256             40      F              1             75
# 11993     621603072             45      F              0             77
# 11994     621644544             41      M              1             63
# 12001     621955584             45      M              1             61
#
#        annual_income  high_education  address_change property_status  \
# ...

# %%
df[df["fraud reported"] == "Y"]
# Out:
#        claim_number  age_of_driver gender marital_status  safety_rating  \
# 1            269568             33      M              1             72
# 5           1244160             42      F              0             68
# 8           2135808             30      F              1             79
# 11          2343168             28      F              1             49
# 13          2592000             42      F              0             92
# ...             ...            ...    ...            ...            ...
# 11986     620960256             40      F              1             75
# 11990     621167616             59      M              0             63
# 11991     621478656             46      M              1             97
# 11995     621665280             42      M              0             71
# 11998     621810432             65      F              1             97
#
#        annual_income  high_education  address_change property_status  \
# ...

# %%
df[df["fraud reported"] == "N"]
# Out:
#        claim_number  age_of_driver gender marital_status  safety_rating  \
# 0            414724             39      M              1             73
# 2            974592             31      M              1             76
# 3            995328             53      F              1             93
# 4           1140480             41      M              1             87
# 6           1700352             50      M              1             89
# ...             ...            ...    ...            ...            ...
# 11996     621706752             31      F              1             70
# 11997     621727488             34      M              1             88
# 11999     621872640             64      F              1             87
# 12000     621914112             34      F              1             70
# 12001     621955584             45      M              1             61
#
#        annual_income  high_education  address_change property_status  \
# ...

# %%
df[df["past_num_of_claims"] > 2]
# Out:
#        claim_number  age_of_driver gender marital_status  safety_rating  \
# 22          4790016             42      F              1             65
# 36          7547904             55      F              1             93
# 52         10305792             48      M              1             94
# 69         13561344             27      F              1             69
# 78         15303168             52      F              1             69
# ...             ...            ...    ...            ...            ...
# 11939     616709376             59      F              1             76
# 11956     618285312             42      F              1             59
# 11964     619176960             49      F              1             42
# 11981     620732160             59      M              1             79
# 11992     621561600             69      M              1             83
#
#        annual_income  high_education  address_change property_status  \
# ...

# %%
df[(df["age_of_driver"] > 25) & (df["age_of_driver"] < 40)]
# Out:
#        claim_number  age_of_driver gender marital_status  safety_rating  \
# 0            414724             39      M              1             73
# 1            269568             33      M              1             72
# 2            974592             31      M              1             76
# 8           2135808             30      F              1             79
# 11          2343168             28      F              1             49
# ...             ...            ...    ...            ...            ...
# 11979     620504064             32      F              1             89
# 11980     620628480             37      F              1             76
# 11996     621706752             31      F              1             70
# 11997     621727488             34      M              1             88
# 12000     621914112             34      F              1             70
#
#        annual_income  high_education  address_change property_status  \
# ...

# %%
df[(df["annual_income"] > 50000) & (df["gender"] == "F")]
# Out:
#        claim_number  age_of_driver gender marital_status  safety_rating  \
# 3            995328             53      F              1             93
# 7           1804032             42      F              1             68
# 9           2198016             49      F              0             57
# 11          2343168             28      F              1             49
# 16          3649536             44      F              0             65
# ...             ...            ...    ...            ...            ...
# 11988     621084672             40      F              0             91
# 11993     621603072             45      F              0             77
# 11996     621706752             31      F              1             70
# 11999     621872640             64      F              1             87
# 12000     621914112             34      F              1             70
#
#        annual_income  high_education  address_change property_status  \
# ...

# %%
df[(df["vehicle_category"] == "Medium") | (df["vehicle_category"] == "Large")]
# Out:
#        claim_number  age_of_driver gender marital_status  safety_rating  \
# 0            414724             39      M              1             73
# 1            269568             33      M              1             72
# 2            974592             31      M              1             76
# 3            995328             53      F              1             93
# 4           1140480             41      M              1             87
# ...             ...            ...    ...            ...            ...
# 11994     621644544             41      M              1             63
# 11995     621665280             42      M              0             71
# 11997     621727488             34      M              1             88
# 11999     621872640             64      F              1             87
# 12001     621955584             45      M              1             61
#
#        annual_income  high_education  address_change property_status  \
# ...

# %%
df[df["fraud reported"] == "Y"].head(10)
# Out:
#     claim_number  age_of_driver gender marital_status  safety_rating  \
# 1         269568             33      M              1             72
# 5        1244160             42      F              0             68
# 8        2135808             30      F              1             79
# 11       2343168             28      F              1             49
# 13       2592000             42      F              0             92
# 14       3525120             23      M              1             82
# 15       3608064             55      M              1             83
# 17       3981312             37      F              0             68
# 21       4748544             27      M              0             36
# 24       5101056             34      M              1             82
#
#     annual_income  high_education  address_change property_status  zip_code  \
# 1         35936.0               0               1             Own     50006
# ...

# %% [markdown]
# # 5. Sorting Data
#
# Sorting arranges the rows of a DataFrame in ascending or descending order based on one or more columns. It helps identify the highest, lowest, or ordered values in the dataset.
#
# ### Questions
#
# 1. Sort the DataFrame by **`vehicle_price`** in **descending order** and display the **top 10 records**.
#
# 2. Sort the DataFrame by **`vehicle_category`** in **ascending order**, and then by **`vehicle_price`** in **descending order**.
#
# 3. Display the **5 cheapest vehicles** based on the **`vehicle_price`** column.
#
# 4. Sort the DataFrame by **`annual_income`** in **ascending order** and display the **first 10 records**.
#
# 5. Sort the DataFrame by **`age_of_driver`** in **descending order** and display the **top 15 oldest drivers**.

# %%
df.sort_values("vehicle_price" , ascending=False).head(10)
# Out:
#        claim_number  age_of_driver gender marital_status  safety_rating  \
# 7139      147515904             35      F              1             63
# 3050      493765632             25      M              1             77
# 2468      402589440             30      F              0             55
# 9724      401386752             41      M              1             38
# 4965      390355200             35      M              1             79
# 6357       70336512             47      F              1             75
# 2681      433071360             59      F              1             62
# 9404      372231936             36      F              1             63
# 10471     476990208             43      F              1             94
# 1706      272947968             64      F              1             89
#
#        annual_income  high_education  address_change property_status  \
# 7139         56875.2               1               0             Own
# ...

# %%
df.sort_values(["vehicle_category" , "vehicle_price"] , ascending=[True , False])
# Out:
#        claim_number  age_of_driver gender marital_status  safety_rating  \
# 7139      147515904             35      F              1             63
# 3050      493765632             25      M              1             77
# 2468      402589440             30      F              0             55
# 2681      433071360             59      F              1             62
# 10471     476990208             43      F              1             94
# ...             ...            ...    ...            ...            ...
# 9792      408312576             52      F              1             79
# 5422      545066496             53      F              1             56
# 4756      320557824             53      M              1             89
# 10874     514729728             35      M              1             83
# 6718      104820480             60      M              1             85
#
#        annual_income  high_education  address_change property_status  \
# ...

# %%
df.sort_values("vehicle_price" , ascending=False).head(5)
# Out:
#       claim_number  age_of_driver gender marital_status  safety_rating  \
# 7139     147515904             35      F              1             63
# 3050     493765632             25      M              1             77
# 2468     402589440             30      F              0             55
# 9724     401386752             41      M              1             38
# 4965     390355200             35      M              1             79
#
#       annual_income  high_education  address_change property_status  zip_code  \
# 7139        56875.2               1               0             Own     80027
# 3050        51532.8               1               1            Rent     20103
# 2468        54412.8               1               1             Own     20159
# 9724        59425.6               1               0             Own     50051
# 4965        56892.8               0               0            Rent     80033
#
# ...

# %%
df.sort_values("annual_income" , ascending=True).head(10)
# Out:
#       claim_number  age_of_driver gender marital_status  safety_rating  \
# 4339     178806528             26      M              0             96
# 321       54514944             38      M              1             79
# 5299     503967744             27      M              1             82
# 6860     118817280             32      M              0             49
# 9499     381189888             31      F              1             90
# 8510     285596928             40      M              1             68
# 9336     365534208             48      F              1             92
# 9417     373496832             65      M              1             74
# 5803      14411520             50      F              1             70
# 17         3981312             37      F              0             68
#
#       annual_income  high_education  address_change property_status  zip_code  \
# 4339           -1.6               0               0             Own     50006
# ...

# %%
df.sort_values("age_of_driver" , ascending=False).head(15)
# Out:
#        claim_number  age_of_driver gender marital_status  safety_rating  \
# 7329      165867264            278      F              1             76
# 7542      186665472            249      M              1             94
# 5644        1078272            180      F              1             87
# 5426      546600960            123      F              1             74
# 7702      202652928            101      M              1             42
# 9039      336006144            100      M              1             78
# 5794       13934592             99      F              1             75
# 821       132482304             96      M              0             47
# 11120     539426304             93      F              1             86
# 2062      331153920             93      M              1             71
# 7858      217810944             93      F              1             76
# 1319      216276480             93      M              1             80
# ...

# %% [markdown]
# # 6. Value Counts
#
# The `value_counts()` function is used to count the frequency of unique values in a column. It helps understand the distribution of categorical data and identify the most common values.
#
# ### Questions
#
# 1. Count the number of drivers belonging to each **`gender`**.
#
# 2. Count the number of vehicles in each **`vehicle_category`**.
#
# 3. Find the most common **`vehicle_color`** in the dataset.
#
# 4. Show the frequency distribution of the **`fraud reported`** column (including missing values, if any).
#
# 5. Count the number of records for each **`marital_status`**.

# %%
df["gender"].value_counts()
# Out:
# gender
# M    6216
# F    5786
# Name: count, dtype: int64

# %%
df["vehicle_category"].value_counts()
# Out:
# vehicle_category
# Compact    4033
# Medium     3996
# Large      3973
# Name: count, dtype: int64

# %%
df["vehicle_color"].value_counts().head(1)
# Out:
# vehicle_color
# red    1766
# Name: count, dtype: int64

# %%
df["fraud reported"].value_counts()
# Out:
# fraud reported
# N    9043
# Y    2951
# Name: count, dtype: int64

# %%
df["marital_status"].value_counts()
# Out:
# marital_status
# 1    8582
# 0    3418
# *       2
# Name: count, dtype: int64

# %% [markdown]
# # 7. Null Value Analysis
#
# Null Value Analysis helps identify missing data in a dataset. Detecting and handling missing values is an important preprocessing step before performing data analysis or building machine learning models.
#
# ### Questions
#
# 1. Check whether the DataFrame contains any missing (null) values.
#
# 2. Count the number of missing values in each column.
#
# 3. Calculate the percentage of missing values for each column.

# %%
df.isnull().sum().sum()
# Out:
# np.int64(8)

# %%
df.isnull().sum()
# Out:
# claim_number          0
# age_of_driver         0
# gender                0
# marital_status        0
# safety_rating         0
# annual_income         0
# high_education        0
# address_change        0
# property_status       0
# zip_code              0
# claim_date            0
# claim_day_of_week     0
# accident_site         0
# past_num_of_claims    0
# witness_present       0
# liab_prct             0
# channel               0
# police_report         0
# age_of_vehicle        0
# vehicle_category      0
# vehicle_price         0
# vehicle_color         0
# total_claim           0
# injury_claim          0
# policy deductible     0
# annual premium        0
# days open             0
# form defects          0
# fraud reported        8
# dtype: int64

# %%
df.isnull().mean() * 100
# Out:
# claim_number          0.000000
# age_of_driver         0.000000
# gender                0.000000
# marital_status        0.000000
# safety_rating         0.000000
# annual_income         0.000000
# high_education        0.000000
# address_change        0.000000
# property_status       0.000000
# zip_code              0.000000
# claim_date            0.000000
# claim_day_of_week     0.000000
# accident_site         0.000000
# past_num_of_claims    0.000000
# witness_present       0.000000
# liab_prct             0.000000
# channel               0.000000
# police_report         0.000000
# age_of_vehicle        0.000000
# vehicle_category      0.000000
# vehicle_price         0.000000
# vehicle_color         0.000000
# total_claim           0.000000
# injury_claim          0.000000
# policy deductible     0.000000
# annual premium        0.000000
# days open             0.000000
# form defects          0.000000
# fraud reported        0.066656
# dtype: float64

# %% [markdown]
# # 8. Correlation between columns

# %%
df.corr(numeric_only=True)
# Out:
#                     claim_number  age_of_driver  safety_rating  annual_income  \
# claim_number            1.000000      -0.010185      -0.012906      -0.079662
# age_of_driver          -0.010185       1.000000       0.005187       0.219343
# safety_rating          -0.012906       0.005187       1.000000      -0.007791
# annual_income          -0.079662       0.219343      -0.007791       1.000000
# high_education         -0.001042       0.000590      -0.006163      -0.007335
# address_change         -0.006054       0.005471       0.007907      -0.005444
# zip_code               -0.000943       0.011337       0.012962      -0.001393
# past_num_of_claims      0.017403      -0.011947       0.001340       0.007499
# liab_prct               0.008321      -0.003274       0.010317       0.002655
# police_report          -0.008376      -0.010522       0.002698       0.002887
# vehicle_price          -0.004997       0.001430      -0.017569       0.008289
# ...

# %% [markdown]
# # 9. Visualization (numerical + categorical)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Histogram

# %%
plt.hist(df["age_of_driver"])
plt.xlim(0, 100)
plt.show()

# %% [markdown]
# ## 2. Boxplot

# %%
plt.boxplot(df["age_of_driver"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ed77609450>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1ed776096d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1ed77609310>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ed77609950>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ed77609a90>],
#  'means': []}

# %% [markdown]
# ## 3. scatter plot

# %%
plt.scatter(df["annual_income"] , df["age_of_driver"])

# %% [markdown]
# ## 4. count plot

# %%
sns.countplot(df["gender"])
# Out:
# <Axes: xlabel='count', ylabel='gender'>

# %% [markdown]
# ## 5. Pie chart

# %%
plt.pie(df["gender"].value_counts() , autopct="%.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x10dbf940440>,
# ...
#  [Text(-0.06187264073725661, 1.0982585198067887, ''),
#   Text(0.06187286767268614, -1.0982585070218935, '')],
#  [Text(-0.03374871312941269, 0.5990501017127938, '51.79%'),
#   Text(0.03374883691237426, -0.5990500947392146, '48.21%')])

# %% [markdown]
# # Pandas profiling

# %%
pip install ydata-profiling
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title="EDA Report")

profile.to_file("report.html")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from ydata_profiling import ProfileReport
#       3 profile = ProfileReport(df, title="EDA Report")
#       5 profile.to_file("report.html")
#
# ModuleNotFoundError: No module named 'ydata_profiling'

# %%
import sys
print(sys.version)
# Out:
# 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]
