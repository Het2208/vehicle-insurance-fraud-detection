# %% [markdown]
# <pre>
# <center><b><h1>Kanasagara Het S.</b></center>
# <pre>

# %%
import pandas as pd

# %%
df = pd.read_csv("preprocessed_housing_ordered.csv")
df.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6456    0.758531 -0.712515            1.538349    -0.561874       -0.555196
# 6467    0.758531 -0.717197            0.108104    -0.225876       -0.261907
# 12898  -0.883609  1.408370           -0.924851     0.057407       -0.085456
# 13254   0.953192 -0.707833           -1.004309     0.557966        0.009922
# 10835   0.823418 -0.913835           -0.289187    -0.283633       -0.197526
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 6456    -0.660945   -0.589923      -0.321654            0.568009          0
# 6467    -0.281232   -0.218507       0.190248            0.392955          0
# 12898   -0.262688   -0.045877      -0.060255           -0.581976          0
# 13254    0.265378   -0.006643       1.183734            0.383422          0
# 10835   -0.354525   -0.187120       0.317158            0.335759          1
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# ...

# %%
df.shape
# Out:
# (20640, 14)

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', '<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY',
#        'NEAR OCEAN'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %%
X = df.drop(columns = "median_house_value")
y = df["median_house_value"]

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -1.327835  1.052548            0.982143    -0.804819       -0.972476
# 1      -1.322844  1.043185           -0.607019     2.045890        1.357143
# 2      -1.332827  1.038503            1.856182    -0.535746       -0.827024
# 3      -1.337818  1.038503            1.856182    -0.624215       -0.719723
# 4      -1.337818  1.038503            1.856182    -0.462404       -0.612423
# ...          ...       ...                 ...          ...             ...
# 20635  -0.758826  1.801647           -0.289187    -0.444985       -0.388283
# 20636  -0.818722  1.806329           -0.845393    -0.888704       -0.922403
# 20637  -0.823713  1.778237           -0.924851    -0.174995       -0.123608
# 20638  -0.873626  1.778237           -0.845393    -0.355600       -0.304827
# 20639  -0.833696  1.750146           -1.004309     0.068408        0.188757
#
# ...

# %%
y
# Out:
# 0        2.129631
# 1        1.314156
# 2        1.258693
# 3        1.165100
# 4        1.172900
#            ...
# 20635   -1.115804
# 20636   -1.124470
# 20637   -0.992746
# 20638   -1.058608
# 20639   -1.017878
# Name: median_house_value, Length: 20640, dtype: float64

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size = 0.3 , random_state = 42)

# %%
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7061    0.773505 -0.796789            0.505394    -0.108071       -0.331056
# 14689   1.237697 -1.330521           -0.686477    -0.207541       -0.006769
# 17323  -0.284652 -0.487786           -0.368645    -0.474322       -0.607654
# 10056  -0.713904  1.698646           -1.163225    -0.836906       -0.920018
# 15750  -1.437644  1.001048            1.856182     0.253138        0.408127
# ...          ...       ...                 ...          ...             ...
# 11284   0.803453 -0.867017            0.505394    -0.598545       -0.800795
# 11964   1.067992 -0.754652            0.346478     0.205466        0.079072
# 5390    0.593818 -0.749970            0.584852    -0.245128        0.076687
# 860    -1.193070  0.912092           -1.083767     0.430534        0.143452
# 15795  -1.422670  1.001048            1.856182     0.728944        1.855496
#
# ...

# %%
y_train
# Out:
# 7061    -0.113142
# 14689   -0.321994
# 17323    0.458817
# 10056   -0.613173
# 15750    2.540411
#            ...
# 11284    0.193636
# 11964   -0.945083
# 5390     0.132107
# 860      0.664202
# 15795    1.023843
# Name: median_house_value, Length: 14448, dtype: float64

# %%
from sklearn.metrics import r2_score
import numpy as np

model = LinearRegression()

model.fit(X_train, y_train)

y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

print("Train R2 Score:", r2_score(y_train, y_train_pred))
print("Test R2 Score :", r2_score(y_test, y_test_pred))
# Out:
# Train R2 Score: 0.6470480227253683
# Test R2 Score : 0.6393611711434395

# %%
print(model.coef_)
# Out:
# [-0.46013883 -0.46118261  0.12062252 -0.11101941  0.3842319  -0.36631703
#   0.1401925   0.64651846 -0.15931572 -0.51528292  1.01830127 -0.21188439
#  -0.13181823]

# %% [markdown]
# # Multiple Linear Regression Algorithm With Gradient Descent Implementation

# %%
import numpy as np

m, n = X.shape

weights = np.zeros(n)
bias = 0

learning_rate = 0.01
epochs = 50000

loss_history = []

for epoch in range(epochs):

    y_pred = np.dot(X, weights) + bias

    error = y_pred - y

    loss = np.mean(error ** 2)
    loss_history.append(loss)

    dw = (2 / m) * np.dot(X.T, error)
    db = (2 / m) * np.sum(error)

    weights -= learning_rate * dw
    bias -= learning_rate * db

    if epoch % 1000 == 0:
        print(f"Epoch {epoch} Loss = {loss:.4f}")
# Out:
# Epoch 0 Loss = 1.0000
# Epoch 1000 Loss = 0.3576
# Epoch 2000 Loss = 0.3559
# Epoch 3000 Loss = 0.3553
# Epoch 4000 Loss = 0.3552
# Epoch 5000 Loss = 0.3551
# Epoch 6000 Loss = 0.3550
# Epoch 7000 Loss = 0.3550

# %%
print("\nWeights:")
print(weights)
# Out:
# Weights:
# [-0.45832463 -0.46584937  0.11567614 -0.08906708  0.25983986 -0.38595343
#   0.25718313  0.63790779  0.07440592 -0.27024686  0.06917042  0.04345774
#   0.11619076]

# %%
print(model.coef_)
# Out:
# [-0.46013883 -0.46118261  0.12062252 -0.11101941  0.3842319  -0.36631703
#   0.1401925   0.64651846 -0.15931572 -0.51528292  1.01830127 -0.21188439
#  -0.13181823]

# %%
# Weights:
# [-0.45832463 -0.46584937  0.11567614 -0.08906708  0.25983986 -0.38595343
#   0.25718313  0.63790779  0.07440592 -0.27024686  0.06917042  0.04345774
#   0.11619076]
